# %% [markdown]
# <a href="https://colab.research.google.com/github/Shreya-07/CMPE258/blob/main/Assignment3partD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Building 3 layer Neural Network using Pytorch tensor with high level primitives

# %%
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import plotly.graph_objects as pltgo

from mpl_toolkits.mplot3d import Axes3D
from sklearn.manifold import TSNE
from sklearn.metrics import mean_squared_error

# %% [markdown]
# #Generating sample data for 3d input and 2d output

# %%
def get_true_labels(X, weights_true, bias_true):
  return (X ** 2) @ weights_true.T + X @ weights_true.T + bias_true.T

# %%
n_samples = 150
input_dim = 3
output_dim = 2

torch.manual_seed(1)
max = 1
min = -1
X = (max - min) * torch.rand((n_samples, input_dim)) + min
print('Sample X: ' + str(X[:2]))

weights_true = torch.tensor([[5., 1., 3.], [2., 1., 1.]])
bias_true = torch.tensor([[1.], [1.]])

y_true = get_true_labels(X, weights_true, bias_true)
print('Sample Y: ' + str(y_true[:2]))
# Out:
# Sample X: tensor([[ 0.5153, -0.4414, -0.1939],
#         [ 0.4694, -0.9414,  0.5997]])
# Sample Y: tensor([[4.1884, 2.1587],
#         [7.2714, 3.2836]])

# %% [markdown]
# #Drawing the 3 Dimensional data plot

# %%
def plot_3d(title, X, y, y_pred=None):
  X_tnse = TSNE(n_components=2, random_state=1234).fit_transform(X)

  fig = plt.figure()
  ax = fig.add_subplot(111, projection='3d')
  ax.scatter(X_tnse[:,0], X_tnse[:,1], y, label='y_true')
  ax.set_title(title)
  if y_pred is not None:
    ax.scatter(X_tnse[:,0], X_tnse[:,1], y_pred, label='y_pred', marker='v')
  plt.legend()
  plt.show()

# %%
def plot_go_3d(x, y, y_pred=None):
  
  fig = pltgo.Figure()
  fig.add_trace(pltgo.Scatter3d(x = x[:,0], y = x[:,1], z = y.reshape([-1]),
                    name='y_true', mode='markers', marker=dict( size=10, color='dodgerblue', colorscale='Viridis', opacity=0.5)))
  if y_pred is not None:
    fig.add_trace(pltgo.Scatter3d(x = x[:,0], y = x[:,1], z = y_pred.reshape([-1]),
                   name='y_pred', mode='markers', marker=dict( size=10, color='goldenrod', colorscale='Viridis', opacity=0.5)))
  fig.update_layout(margin=dict(r=20, b=10, l=10, t=10))
  fig.show()

# %%
plot_3d('Output 1', X, y_true[:,0])
plot_3d('Output 2', X, y_true[:,1])
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,

# %%
X_reduced = TSNE(n_components=2).fit_transform(X)
y_true_reduced = TSNE(n_components=1).fit_transform(y_true)
plot_go_3d(X_reduced,y_true_reduced)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="696aea3f-f286-492e-ad10-a53d412dbd1b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("696aea3f-f286-492e-ad10-a53d412dbd1b")) {                    Plotly.newPlot(                        "696aea3f-f286-492e-ad10-a53d412dbd1b",                        [{"marker":{"color":"dodgerblue","colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"opacity":0.5,"size":10},"mode":"markers","name":"y_true","x":[-0.3814639747142792,4.223473072052002,-2.0486557483673096,-1.0089218616485596,-0.7843872904777527,-1.029589295387268,2.571563959121704,-5.881661891937256,-1.9776148796081543,4.613290309906006,3.4271037578582764,-7.8462395668029785,4.7873382568359375,-6.1360554695129395,1.9211452007293701,3.7608609199523926,-3.8075709342956543,-5.473255634307861,4.003340721130371,-5.504136562347412,-5.153160572052002,1.1180548667907715,-2.3388988971710205,-6.223109245300293,2.901984930038452,1.8853273391723633,-7.310976982116699,-6.302996635437012,-1.3368942737579346,4.334958553314209,3.3037056922912598,-2.5070042610168457,0.30845457315444946,-5.185695171356201,1.241953730583191,-6.849393367767334,3.557358741760254,2.5895392894744873,2.8993308544158936,-0.8028000593185425,-3.256767749786377,-6.483100891113281,-3.2001588344573975,5.797006130218506,5.079436779022217,4.010659694671631,-7.471973419189453,1.0805596113204956,2.384052276611328,3.363764524459839,-5.3343353271484375,-4.254147052764893,-1.7090038061141968,0.370415598154068,0.7407397031784058,-1.7114824056625366,-7.138839244842529,2.349055528640747,5.179542541503906,2.0564653873443604,-3.68652606010437,0.1454365998506546,-8.32911205291748,-5.742985248565674,-2.5828754901885986,-4.544043064117432,6.042700290679932,-6.879406929016113,1.2114356756210327,0.1939014196395874,-0.9678359031677246,4.615052223205566,0.009306232444941998,5.362087726593018,-1.6132313013076782,-2.5502865314483643,3.5388741493225098,-6.715625286102295,-4.525974750518799,1.671830177307129,-3.4297995567321777,0.8729872703552246,-7.277377605438232,3.293278932571411,-0.09109633415937424,-4.240346431732178,-0.6802133917808533,5.208497047424316,3.0686185359954834,-7.543129920959473,1.3125624656677246,0.5326645374298096,-6.5249176025390625,1.1725198030471802,2.5073821544647217,-0.5133579969406128,-1.2664209604263306,-4.76503324508667,-3.1017870903015137,-3.630338191986084,0.6644743084907532,-4.280063152313232,-6.6833815574646,1.5025161504745483,-2.6008999347686768,-2.9939310550689697,1.8664246797561646,-3.29768705368042,-1.3576421737670898,-2.768981695175171,4.293189525604248,-6.084112167358398,-0.9992877840995789,-3.204129934310913,-7.221466541290283,-4.196555137634277,-2.146289587020874,-2.09641170501709,4.60870885848999,0.6828529834747314,-0.405000776052475,-1.5699633359909058,-2.6334388256073,1.0810116529464722,1.4271085262298584,2.253066301345825,1.1528902053833008,-7.181024074554443,-5.1187872886657715,-1.545555591583252,0.8449794054031372,-5.751838207244873,4.977230072021484,4.403528213500977,-3.589975118637085,-6.871928691864014,0.7957885265350342,0.7910236120223999,0.22573108971118927,0.4931296110153198,-6.367762565612793,4.497159481048584,0.6562084555625916,-3.3495607376098633,0.2965758442878723,-5.524737358093262,1.9794706106185913,5.880996227264404,-0.49706462025642395,-1.2720069885253906],"y":[6.572803020477295,-7.889225959777832,-2.425077199935913,-2.1905648708343506,5.960784912109375,-1.7328648567199707,4.043546199798584,2.72914457321167,-6.348541736602783,-7.895501613616943,-1.00791919231414 ...

# %% [markdown]
# #Build Nueral Network

# %%
class NeuralNet(nn.Module):
  def __init__(self, num_inputs=3, num_hidden=[2], num_outputs=2, activation=None):
    super(NeuralNet, self).__init__()

    self.num_inputs = num_inputs
    self.num_hidden = num_hidden
    self.num_outputs = num_outputs

    layers_nodes = [self.num_inputs] + self.num_hidden + [self.num_outputs]
    
    layers = []
    for i in range(len(layers_nodes[:-1])):
      # Don't add activation function to last layer because this is a regression problem
      if i == len(layers_nodes[:-1]) - 1:
        layers.append(nn.Linear(layers_nodes[i], layers_nodes[i + 1]))
      else:
        layers.append(nn.Linear(layers_nodes[i], layers_nodes[i + 1]))
        if activation == 'relu':
          layers.append(nn.ReLU())

    self.layers = nn.ModuleList(layers)

  def forward(self, x):
    curr_out = X
    for layer in self.layers:
      curr_out = layer(curr_out)
    return curr_out
  
  def fit(self, X, y_true, lr, epochs):
    loss_fn  = nn.MSELoss()
    optimizer = torch.optim.SGD(self.parameters(), lr=lr)
    for epoch in range(epochs):
      optimizer.zero_grad()
      y_pred = self.forward(X)
      error = loss_fn(y_pred, y_true)
      print(error)
      error.backward()
      optimizer.step()

# %% [markdown]
# #HyperParameters

# %%
epochs = 150
lr = 0.01

n_inputs = X.shape[1]
n_outputs = y_true.shape[1]

# %% [markdown]
# #Training NN withuot any activation function

# %%
model = NeuralNet(num_inputs=n_inputs, num_hidden=[4, 3], num_outputs=n_outputs, activation=None)
print('Neural Network Architecture:')
print(model.layers)
print()

for name, param in model.named_parameters():
  print(f"Layer: {name} | Size: {param.size()} | Values : {param[:2]} \n")

model.fit(X, y_true, lr, epochs)

y_pred = model.forward(X).detach().numpy()
err = mean_squared_error(y_true, y_pred)
print('Final Mean Squared Error: {}'.format(err))
# Out:
# Neural Network Architecture:
# ModuleList(
#   (0): Linear(in_features=3, out_features=4, bias=True)
#   (1): Linear(in_features=4, out_features=3, bias=True)
#   (2): Linear(in_features=3, out_features=2, bias=True)
# )
#
# Layer: layers.0.weight | Size: torch.Size([4, 3]) | Values : tensor([[ 0.1934,  0.3160,  0.5723],
#         [-0.0603,  0.5554,  0.3709]], grad_fn=<SliceBackward0>)
#
# Layer: layers.0.bias | Size: torch.Size([4]) | Values : tensor([0.4212, 0.1730], grad_fn=<SliceBackward0>)
#
# Layer: layers.1.weight | Size: torch.Size([3, 4]) | Values : tensor([[-0.3560, -0.1093,  0.0049, -0.2889],
#         [-0.1278, -0.2156,  0.4765,  0.4248]], grad_fn=<SliceBackward0>)
#
# Layer: layers.1.bias | Size: torch.Size([3]) | Values : tensor([ 0.1843, -0.3667], grad_fn=<SliceBackward0>)
#
# Layer: layers.2.weight | Size: torch.Size([2, 3]) | Values : tensor([[-0.3133,  0.0918,  0.1912],
#         [ 0.4982, -0.3029, -0.4542]], grad_fn=<SliceBackward0>)
#
# Layer: layers.2.bias | Size: torch.Size([2]) | Values : tensor([0.5342, 0.2424], grad_fn=<SliceBackward0>)
#
# tensor(17.7812, grad_fn=<MseLossBackward0>)
# tensor(17.4592, grad_fn=<MseLossBackward0>)
# tensor(17.1462, grad_fn=<MseLossBackward0>)
# tensor(16.8395, grad_fn=<MseLossBackward0>)
# tensor(16.5365, grad_fn=<MseLossBackward0>)
# tensor(16.2350, grad_fn=<MseLossBackward0>)
# tensor(15.9330, grad_fn=<MseLossBackward0>)
# tensor(15.6288, grad_fn=<MseLossBackward0>)
# tensor(15.3205, grad_fn=<MseLossBackward0>)
# tensor(15.0066, grad_fn=<MseLossBackward0>)
# tensor(14.6858, grad_fn=<MseLossBackward0>)
# tensor(14.3566, grad_fn=<MseLossBackward0>)
# tensor(14.0178, grad_fn=<MseLossBackward0>)
# tensor(13.6684, grad_fn=<MseLossBackward0>)
# tensor(13.3074, grad_fn=<MseLossBackward0>)
# tensor(12.9340, grad_fn=<MseLossBackward0>)
# tensor(12.5479, grad_fn=<MseLossBackward0>)
# tensor(12.1487, grad_fn=<MseLossBackward0>)
# tensor(11.7367, grad_fn=<MseLossBackward0>)
# tensor(11.3125, grad_fn=<MseLossBackward0>)
# tensor(10.8772, grad_fn=<MseLossBackward0>)
# tensor(10.4325, grad_fn=<MseLossBackward0>)
# tensor(9.9806, grad_fn=<MseLossBackward0>)
# tensor(9.5243, grad_fn=<MseLossBackward0>)
# tensor(9.0671, grad_fn=<MseLossBackward0>)
# tensor(8.6129, grad_fn=<MseLossBackward0>)
# tensor(8.1658, grad_fn=<MseLossBackward0>)
# tensor(7.7303, grad_fn=<MseLossBackward0>)
# tensor(7.3104, grad_fn=<MseLossBackward0>)
# tensor(6.9099, grad_fn=<MseLossBackward0>)
# tensor(6.5318, grad_fn=<MseLossBackward0>)
# tensor(6.1783, grad_fn=<MseLossBackward0>)
# tensor(5.8504, grad_fn=<MseLossBackward0>)
# tensor(5.5480, grad_fn=<MseLossBackward0>)
# tensor(5.2704, grad_fn=<MseLossBackward0>)
# tensor(5.0159, grad_fn=<MseLossBackward0>)
# tensor(4.7823, grad_fn=<MseLossBackward0>)
# tensor(4.5672, grad_fn=<MseLossBackward0>)
# tensor(4.3684, grad_fn=<MseLossBackward0>)
# tensor(4.1836, grad_fn=<MseLossBackward0>)
# tensor(4.0109, grad_fn=<MseLossBackward0>)
# tensor(3.8488, grad_fn=<MseLossBackward0>)
# tensor(3.6962, grad_fn=<MseLossBackward0>)
# tensor(3.5521, grad_fn=<MseLossBackward0>)
# tensor(3.4159, grad_fn=<MseLossBackward0>)
# tensor(3.2873, grad_fn=<MseLossBackward0>)
# tensor(3.1661, grad_fn=<MseLossBackward0>)
# tensor(3.0519, grad_fn=<MseLossBackward0>)
# tensor(2.9449, grad_fn=<MseLossBackward0>)
# tensor(2.8448, grad_fn=<MseLossBackward0>)
# tensor(2.7516, grad_fn=<MseLossBackward0>)
# tensor(2.6653, grad_fn=<MseLossBackward0>)
# tensor(2.5856, grad_fn=<MseLossBackward0>)
# tensor(2.5124, grad_fn=<MseLossBackward0>)
# tensor(2.4456, grad_fn=<MseLossBackward0>)
# tensor(2.3847, grad_fn=<MseLossBackward0>)
# tensor(2.3297, grad_fn=<MseLossBackward0>)
# tensor(2.2801, grad_fn=<MseLossBackward0>)
# tensor(2.2356, grad_fn=<MseLossBackward0>)
# tensor(2.1959, grad_fn=<MseLossBackward0>)
# tensor(2.1605, grad_fn=<MseLossBackward0>)
# tensor(2.1292, grad_fn=<MseLossBackward0>)
# tensor(2.1016, grad_fn=<MseLossBackward0>)
# tensor(2.0773, grad_fn=<MseLossBackward0>)
# tensor(2.0560, grad_fn=<MseLossBackward0>)
# tensor(2.0373, grad_fn=<MseLossBackward0>)
# tensor(2.0210, grad_fn=<MseLossBackward0>)
# tensor(2.0068, grad_fn=<MseLossBackward0>)
# tensor(1.9945, grad_fn=<MseLossBackward0>)
# tensor(1.9837, grad_fn=<MseLossBackward0>)
# tensor(1.9744, grad_fn=<MseLossBackward0>)
# tensor(1.9663, grad_fn=<MseLossBackward0>)
# tensor(1.9593, grad_fn=<MseLossBackward0>)
# tensor(1.9531, grad_fn=<MseLossBackward0>)
# tensor(1.9478, grad_fn=<MseLossBackward0>)
# tensor(1.9432, grad_fn=<MseLossBackward0>)
# tensor(1.9391, grad_fn=<MseLossBackward0>)
# tensor(1.9355, grad_fn=<MseLossBackward0>)
# tensor(1.9324, grad_fn=<MseLossBackward0>)
# tensor(1.9296, grad_fn=<MseLossBackward0>)
# tensor(1.9272, grad_fn=<MseLossBackward0>)
# tensor(1.9250, grad_fn=<MseLossBackward0>)
# tensor(1.9230, grad_fn=<MseLossBackward0>)
# tensor(1.9212, grad_fn=<MseLossBackward0>)
# tensor(1.9196, grad_fn=<MseLossBackward0>)
# tensor(1.9182, grad_fn=<MseLossBackward0>)
# tensor(1.9169, grad_fn=<MseLossBackward0>)
# tensor(1.9156, grad_fn=<MseLossBackward0>)
# tensor(1.9145, grad_fn=<MseLossBackward0>)
# tensor(1.9134, grad_fn=<MseLossBackward0>)
# tensor(1.9125, grad_fn=<MseLossBackward0>)
# tensor(1.9115, grad_fn=<MseLossBackward0>)
# tensor(1.9107, grad_fn=<MseLossBackward0>)
# tensor(1.9099, grad_fn=<MseLossBackward0>)
# tensor(1.9091, grad_fn=<MseLossBackward0>)
# tensor(1.9083, grad_fn=<MseLossBackward0>)
# tensor(1.9076, grad_fn=<MseLossBackward0>)
# tensor(1.9069, grad_fn=<MseLossBackward0>)
# tensor(1.9063, grad_fn=<MseLossBackward0>)
# tensor(1.9057, grad_fn=<MseLossBackward0>)
# tensor(1.9050, grad_fn=<MseLossBackward0>)
# tensor(1.9045, grad_fn=<MseLossBackward0>)
# tensor(1.9039, grad_fn=<MseLossBackward0>)
# tensor(1.9033, grad_fn=<MseLossBackward0>)
# tensor(1.9028, grad_fn=<MseLossBackward0>)
# tensor(1.9023, grad_fn=<MseLossBackward0>)
# tensor(1.9017, grad_fn=<MseLossBackward0>)
# tensor(1.9012, grad_fn=<MseLossBackward0>)
# tensor(1.9007, grad_fn=<MseLossBackward0>)
# tensor(1.9003, grad_fn=<MseLossBackward0>)
# tensor(1.8998, grad_fn=<MseLossBackward0>)
# tensor(1.8993, grad_fn=<MseLossBackward0>)
# tensor(1.8989, grad_fn=<MseLossBackward0>)
# tensor(1.8984, grad_fn=<MseLossBackward0>)
# tensor(1.8980, grad_fn=<MseLossBackward0>)
# tensor(1.8976, grad_fn=<MseLossBackward0>)
# tensor(1.8972, grad_fn=<MseLossBackward0>)
# tensor(1.8967, grad_fn=<MseLossBackward0>)
# tensor(1.8963, grad_fn=<MseLossBackward0>)
# tensor(1.8959, grad_fn=<MseLossBackward0>)
# tensor(1.8955, grad_fn=<MseLossBackward0>)
# tensor(1.8952, grad_fn=<MseLossBackward0>)
# tensor(1.8948, grad_fn=<MseLossBackward0>)
# tensor(1.8944, grad_fn=<MseLossBackward0>)
# tensor(1.8940, grad_fn=<MseLossBackward0>)
# tensor(1.8937, grad_fn=<MseLossBackward0>)
# tensor(1.8933, grad_fn=<MseLossBackward0>)
# tensor(1.8929, grad_fn=<MseLossBackward0>)
# tensor(1.8926, grad_fn=<MseLossBackward0>)
# tensor(1.8923, grad_fn=<MseLossBackward0>)
# tensor(1.8919, grad_fn=<MseLossBackward0>)
# tensor(1.8916, grad_fn=<MseLossBackward0>)
# tensor(1.8912, grad_fn=<MseLossBackward0>)
# tensor(1.8909, grad_fn=<MseLossBackward0>)
# tensor(1.8906, grad_fn=<MseLossBackward0>)
# tensor(1.8903, grad_fn=<MseLossBackward0>)
# tensor(1.8900, grad_fn=<MseLossBackward0>)
# tensor(1.8897, grad_fn=<MseLossBackward0>)
# tensor(1.8893, grad_fn=<MseLossBackward0>)
# tensor(1.8890, grad_fn=<MseLossBackward0>)
# tensor(1.8887, grad_fn=<MseLossBackward0>)
# tensor(1.8884, grad_fn=<MseLossBackward0>)
# tensor(1.8882, grad_fn=<MseLossBackward0>)
# tensor(1.8879, grad_fn=<MseLossBackward0>)
# tensor(1.8876, grad_fn=<MseLossBackward0>)
# tensor(1.8873, grad_fn=<MseLossBackward0>)
# tensor(1.8870, grad_fn=<MseLossBackward0>)
# tensor(1.8867, grad_fn=<MseLossBackward0>)
# tensor(1.8865, grad_fn=<MseLossBackward0>)
# tensor(1.8862, grad_fn=<MseLossBackward0>)
# Final Mean Squared Error: 1.8859221935272217

# %%
plot_3d('Output for y1', X, y_true[:,0], y_pred[:,0])
plot_3d('Output for y2', X, y_true[:,1], y_pred[:,1])
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning:
#
# The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning:
#
# The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning:
#
# The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning:
#
# The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.

# %%
X_plot = TSNE(n_components=2).fit_transform(X)
y_true_plot = TSNE(n_components=1).fit_transform(y_true)
y_pred_plot = TSNE(n_components=1).fit_transform(y_pred)
plot_go_3d(X_plot,y_true_plot,y_pred_plot)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning:
#
# The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning:
#
# The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning:
#
# The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning:
#
# The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning:
#
# The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning:
#
# The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="fa3f84d4-85e1-427e-9b15-fa0659a6e391" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fa3f84d4-85e1-427e-9b15-fa0659a6e391")) {                    Plotly.newPlot(                        "fa3f84d4-85e1-427e-9b15-fa0659a6e391",                        [{"marker":{"color":"dodgerblue","colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"opacity":0.5,"size":10},"mode":"markers","name":"y_true","x":[-7.72872257232666,-4.896478176116943,3.225738048553467,2.448385238647461,-6.877311706542969,1.9959614276885986,4.422236919403076,-0.9971878528594971,0.8143495321273804,-5.1546478271484375,0.7283259630203247,-3.05465030670166,-2.974290370941162,5.7206010818481445,4.481456756591797,-5.364583492279053,-5.6966633796691895,3.3306543827056885,3.6970326900482178,4.193470478057861,4.288397312164307,-8.713324546813965,6.689340591430664,3.7048802375793457,-0.9187779426574707,0.7188692688941956,3.550157070159912,0.46265143156051636,-9.845293045043945,-2.6583077907562256,-5.275264739990234,-8.176945686340332,4.8554534912109375,6.32989501953125,5.707706928253174,5.132404804229736,-0.9172652959823608,5.8196330070495605,0.7512840628623962,-9.695375442504883,1.5489835739135742,3.367311477661133,0.06924418359994888,-6.7634968757629395,-0.17319896817207336,1.669036626815796,-3.134351968765259,-3.3768906593322754,-2.198659658432007,0.28322634100914,6.353086948394775,-8.257792472839355,-0.8204658031463623,-3.0191595554351807,5.974575519561768,-7.041783809661865,-1.9277852773666382,-0.03140348941087723,0.3942299783229828,-3.412135601043701,-5.735960483551025,-2.132944107055664,-2.3867385387420654,2.49153208732605,1.0617451667785645,3.264033317565918,-6.706262588500977,4.748301982879639,2.687417507171631,0.6261399388313293,6.947403430938721,0.20421940088272095,-9.21741771697998,-5.096734046936035,-1.7268091440200806,0.08596146106719971,4.471680164337158,5.27042818069458,1.7017489671707153,6.3744730949401855,0.5595583319664001,-5.178380966186523,-2.907508134841919,4.947314739227295,2.4627907276153564,3.8273653984069824,-0.5827464461326599,-4.627727508544922,-4.1240010261535645,4.813920021057129,1.1334757804870605,-8.834051132202148,-0.35075435042381287,-1.7375092506408691,4.099873065948486,-1.9132355451583862,2.289573907852173,3.811274290084839,-7.237795352935791,-7.511609077453613,-2.038321018218994,-5.416849136352539,4.858460903167725,-8.214456558227539,-0.49608439207077026,-0.417819082736969,3.7602741718292236,-6.101600646972656,-8.583465576171875,-6.674762725830078,-0.7227404117584229,0.08928875625133514,-2.497083902359009,-8.287589073181152,5.069405555725098,-6.563262462615967,-1.1309564113616943,-7.606475353240967,-0.35446447134017944,3.2888007164001465,-2.2784910202026367,2.956461191177368,-1.278403878211975,-3.54325532913208,-2.2852628231048584,-3.1373343467712402,3.444417953491211,4.46773099899292,4.5722174644470215,-7.491897106170654,2.5310251712799072,6.065945148468018,-1.5034761428833008,-4.122546195983887,-6.211538314819336,-2.492377758026123,-7.707411766052246,5.980226039886475,6.6654157638549805,-9.371811866760254,5.3663482666015625,-2.049609661102295,-3.6108853816986084,-5.9589524269104,1.2600945234298706,3.8187146186828613,6.168222904205322,-5.824345111846924,6.087619304656982,-9.91677474975586],"y":[-0.9620915651321411,-3.5762383937835693,-1.8504092693328857,-2.4749860763549805,-0.7104139924049377,-2.309528350830078,-7.525212287902832,6.108332633972168,-0.3261505663394928,-3.9168543815612793,-7.32326602935791,5.6 ...

# %% [markdown]
# #Training NN with ReLU activation function

# %%
model = NeuralNet(num_inputs=n_inputs, num_hidden=[4, 3], num_outputs=n_outputs, activation='relu')
print('Neural Network Architecture:')
print(model.layers)
print()

for name, param in model.named_parameters():
  print(f"Layer: {name} | Size: {param.size()} | Values : {param[:2]} \n")

model.fit(X, y_true, lr, epochs)

y_pred = model.forward(X).detach().numpy()
err = mean_squared_error(y_true, y_pred)
print('Final Mean Squared Error: {}'.format(err))
# Out:
# Neural Network Architecture:
# ModuleList(
#   (0): Linear(in_features=3, out_features=4, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=4, out_features=3, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=3, out_features=2, bias=True)
# )
#
# Layer: layers.0.weight | Size: torch.Size([4, 3]) | Values : tensor([[ 0.2806,  0.2078, -0.2044],
#         [ 0.3473, -0.5040,  0.0803]], grad_fn=<SliceBackward0>)
#
# Layer: layers.0.bias | Size: torch.Size([4]) | Values : tensor([-0.4798, -0.5192], grad_fn=<SliceBackward0>)
#
# Layer: layers.2.weight | Size: torch.Size([3, 4]) | Values : tensor([[-0.2961, -0.2114, -0.4427,  0.3073],
#         [-0.1145, -0.3155,  0.1302, -0.3739]], grad_fn=<SliceBackward0>)
#
# Layer: layers.2.bias | Size: torch.Size([3]) | Values : tensor([-0.3297, -0.2707], grad_fn=<SliceBackward0>)
#
# Layer: layers.4.weight | Size: torch.Size([2, 3]) | Values : tensor([[-0.5709, -0.4280,  0.2637],
#         [-0.1891, -0.2297, -0.4776]], grad_fn=<SliceBackward0>)
#
# Layer: layers.4.bias | Size: torch.Size([2]) | Values : tensor([0.2340, 0.0408], grad_fn=<SliceBackward0>)
#
# tensor(19.2371, grad_fn=<MseLossBackward0>)
# tensor(19.0341, grad_fn=<MseLossBackward0>)
# tensor(18.8351, grad_fn=<MseLossBackward0>)
# tensor(18.6400, grad_fn=<MseLossBackward0>)
# tensor(18.4488, grad_fn=<MseLossBackward0>)
# tensor(18.2615, grad_fn=<MseLossBackward0>)
# tensor(18.0778, grad_fn=<MseLossBackward0>)
# tensor(17.8978, grad_fn=<MseLossBackward0>)
# tensor(17.7213, grad_fn=<MseLossBackward0>)
# tensor(17.5484, grad_fn=<MseLossBackward0>)
# tensor(17.3788, grad_fn=<MseLossBackward0>)
# tensor(17.2126, grad_fn=<MseLossBackward0>)
# tensor(17.0497, grad_fn=<MseLossBackward0>)
# tensor(16.8900, grad_fn=<MseLossBackward0>)
# tensor(16.7335, grad_fn=<MseLossBackward0>)
# tensor(16.5800, grad_fn=<MseLossBackward0>)
# tensor(16.4296, grad_fn=<MseLossBackward0>)
# tensor(16.2821, grad_fn=<MseLossBackward0>)
# tensor(16.1375, grad_fn=<MseLossBackward0>)
# tensor(15.9958, grad_fn=<MseLossBackward0>)
# tensor(15.8568, grad_fn=<MseLossBackward0>)
# tensor(15.7205, grad_fn=<MseLossBackward0>)
# tensor(15.5869, grad_fn=<MseLossBackward0>)
# tensor(15.4559, grad_fn=<MseLossBackward0>)
# tensor(15.3274, grad_fn=<MseLossBackward0>)
# tensor(15.2014, grad_fn=<MseLossBackward0>)
# tensor(15.0779, grad_fn=<MseLossBackward0>)
# tensor(14.9567, grad_fn=<MseLossBackward0>)
# tensor(14.8379, grad_fn=<MseLossBackward0>)
# tensor(14.7214, grad_fn=<MseLossBackward0>)
# tensor(14.6071, grad_fn=<MseLossBackward0>)
# tensor(14.4950, grad_fn=<MseLossBackward0>)
# tensor(14.3851, grad_fn=<MseLossBackward0>)
# tensor(14.2773, grad_fn=<MseLossBackward0>)
# tensor(14.1716, grad_fn=<MseLossBackward0>)
# tensor(14.0679, grad_fn=<MseLossBackward0>)
# tensor(13.9662, grad_fn=<MseLossBackward0>)
# tensor(13.8665, grad_fn=<MseLossBackward0>)
# tensor(13.7687, grad_fn=<MseLossBackward0>)
# tensor(13.6728, grad_fn=<MseLossBackward0>)
# tensor(13.5787, grad_fn=<MseLossBackward0>)
# tensor(13.4864, grad_fn=<MseLossBackward0>)
# tensor(13.3959, grad_fn=<MseLossBackward0>)
# tensor(13.3071, grad_fn=<MseLossBackward0>)
# tensor(13.2199, grad_fn=<MseLossBackward0>)
# tensor(13.1344, grad_fn=<MseLossBackward0>)
# tensor(13.0505, grad_fn=<MseLossBackward0>)
# tensor(12.9682, grad_fn=<MseLossBackward0>)
# tensor(12.8874, grad_fn=<MseLossBackward0>)
# tensor(12.8081, grad_fn=<MseLossBackward0>)
# tensor(12.7303, grad_fn=<MseLossBackward0>)
# tensor(12.6540, grad_fn=<MseLossBackward0>)
# tensor(12.5790, grad_fn=<MseLossBackward0>)
# tensor(12.5055, grad_fn=<MseLossBackward0>)
# tensor(12.4332, grad_fn=<MseLossBackward0>)
# tensor(12.3623, grad_fn=<MseLossBackward0>)
# tensor(12.2927, grad_fn=<MseLossBackward0>)
# tensor(12.2243, grad_fn=<MseLossBackward0>)
# tensor(12.1572, grad_fn=<MseLossBackward0>)
# tensor(12.0913, grad_fn=<MseLossBackward0>)
# tensor(12.0266, grad_fn=<MseLossBackward0>)
# tensor(11.9631, grad_fn=<MseLossBackward0>)
# tensor(11.9007, grad_fn=<MseLossBackward0>)
# tensor(11.8394, grad_fn=<MseLossBackward0>)
# tensor(11.7792, grad_fn=<MseLossBackward0>)
# tensor(11.7202, grad_fn=<MseLossBackward0>)
# tensor(11.6622, grad_fn=<MseLossBackward0>)
# tensor(11.6053, grad_fn=<MseLossBackward0>)
# tensor(11.5494, grad_fn=<MseLossBackward0>)
# tensor(11.4944, grad_fn=<MseLossBackward0>)
# tensor(11.4403, grad_fn=<MseLossBackward0>)
# tensor(11.3872, grad_fn=<MseLossBackward0>)
# tensor(11.3349, grad_fn=<MseLossBackward0>)
# tensor(11.2834, grad_fn=<MseLossBackward0>)
# tensor(11.2329, grad_fn=<MseLossBackward0>)
# tensor(11.1832, grad_fn=<MseLossBackward0>)
# tensor(11.1343, grad_fn=<MseLossBackward0>)
# tensor(11.0863, grad_fn=<MseLossBackward0>)
# tensor(11.0390, grad_fn=<MseLossBackward0>)
# tensor(10.9925, grad_fn=<MseLossBackward0>)
# tensor(10.9468, grad_fn=<MseLossBackward0>)
# tensor(10.9018, grad_fn=<MseLossBackward0>)
# tensor(10.8576, grad_fn=<MseLossBackward0>)
# tensor(10.8141, grad_fn=<MseLossBackward0>)
# tensor(10.7712, grad_fn=<MseLossBackward0>)
# tensor(10.7291, grad_fn=<MseLossBackward0>)
# tensor(10.6877, grad_fn=<MseLossBackward0>)
# tensor(10.6469, grad_fn=<MseLossBackward0>)
# tensor(10.6068, grad_fn=<MseLossBackward0>)
# tensor(10.5673, grad_fn=<MseLossBackward0>)
# tensor(10.5285, grad_fn=<MseLossBackward0>)
# tensor(10.4902, grad_fn=<MseLossBackward0>)
# tensor(10.4526, grad_fn=<MseLossBackward0>)
# tensor(10.4156, grad_fn=<MseLossBackward0>)
# tensor(10.3792, grad_fn=<MseLossBackward0>)
# tensor(10.3434, grad_fn=<MseLossBackward0>)
# tensor(10.3081, grad_fn=<MseLossBackward0>)
# tensor(10.2733, grad_fn=<MseLossBackward0>)
# tensor(10.2392, grad_fn=<MseLossBackward0>)
# tensor(10.2055, grad_fn=<MseLossBackward0>)
# tensor(10.1724, grad_fn=<MseLossBackward0>)
# tensor(10.1397, grad_fn=<MseLossBackward0>)
# tensor(10.1075, grad_fn=<MseLossBackward0>)
# tensor(10.0758, grad_fn=<MseLossBackward0>)
# tensor(10.0446, grad_fn=<MseLossBackward0>)
# tensor(10.0138, grad_fn=<MseLossBackward0>)
# tensor(9.9835, grad_fn=<MseLossBackward0>)
# tensor(9.9536, grad_fn=<MseLossBackward0>)
# tensor(9.9241, grad_fn=<MseLossBackward0>)
# tensor(9.8951, grad_fn=<MseLossBackward0>)
# tensor(9.8665, grad_fn=<MseLossBackward0>)
# tensor(9.8383, grad_fn=<MseLossBackward0>)
# tensor(9.8104, grad_fn=<MseLossBackward0>)
# tensor(9.7830, grad_fn=<MseLossBackward0>)
# tensor(9.7560, grad_fn=<MseLossBackward0>)
# tensor(9.7292, grad_fn=<MseLossBackward0>)
# tensor(9.7029, grad_fn=<MseLossBackward0>)
# tensor(9.6768, grad_fn=<MseLossBackward0>)
# tensor(9.6512, grad_fn=<MseLossBackward0>)
# tensor(9.6258, grad_fn=<MseLossBackward0>)
# tensor(9.6008, grad_fn=<MseLossBackward0>)
# tensor(9.5763, grad_fn=<MseLossBackward0>)
# tensor(9.5520, grad_fn=<MseLossBackward0>)
# tensor(9.5281, grad_fn=<MseLossBackward0>)
# tensor(9.5044, grad_fn=<MseLossBackward0>)
# tensor(9.4809, grad_fn=<MseLossBackward0>)
# tensor(9.4576, grad_fn=<MseLossBackward0>)
# tensor(9.4347, grad_fn=<MseLossBackward0>)
# tensor(9.4119, grad_fn=<MseLossBackward0>)
# tensor(9.3894, grad_fn=<MseLossBackward0>)
# tensor(9.3671, grad_fn=<MseLossBackward0>)
# tensor(9.3450, grad_fn=<MseLossBackward0>)
# tensor(9.3231, grad_fn=<MseLossBackward0>)
# tensor(9.3014, grad_fn=<MseLossBackward0>)
# tensor(9.2799, grad_fn=<MseLossBackward0>)
# tensor(9.2585, grad_fn=<MseLossBackward0>)
# tensor(9.2372, grad_fn=<MseLossBackward0>)
# tensor(9.2161, grad_fn=<MseLossBackward0>)
# tensor(9.1951, grad_fn=<MseLossBackward0>)
# tensor(9.1742, grad_fn=<MseLossBackward0>)
# tensor(9.1534, grad_fn=<MseLossBackward0>)
# tensor(9.1327, grad_fn=<MseLossBackward0>)
# tensor(9.1121, grad_fn=<MseLossBackward0>)
# tensor(9.0916, grad_fn=<MseLossBackward0>)
# tensor(9.0711, grad_fn=<MseLossBackward0>)
# tensor(9.0506, grad_fn=<MseLossBackward0>)
# tensor(9.0300, grad_fn=<MseLossBackward0>)
# tensor(9.0092, grad_fn=<MseLossBackward0>)
# tensor(8.9883, grad_fn=<MseLossBackward0>)
# tensor(8.9674, grad_fn=<MseLossBackward0>)
# Final Mean Squared Error: 8.94633960723877

# %%
plot_3d('Output y1 with ReLU', X, y_true[:,0], y_pred[:,0])
plot_3d('Output y2 with ReLU', X, y_true[:,1], y_pred[:,1])
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning:
#
# The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning:
#
# The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning:
#
# The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning:
#
# The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.

# %%
X_plot = TSNE(n_components=2).fit_transform(X)
y_true_plot = TSNE(n_components=1).fit_transform(y_true)
y_pred_plot = TSNE(n_components=1).fit_transform(y_pred)
plot_go_3d(X_plot,y_true_plot,y_pred_plot)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning:
#
# The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning:
#
# The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning:
#
# The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning:
#
# The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning:
#
# The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning:
#
# The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="caba95e2-4384-4e02-b96f-4b87d6dee6fa" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("caba95e2-4384-4e02-b96f-4b87d6dee6fa")) {                    Plotly.newPlot(                        "caba95e2-4384-4e02-b96f-4b87d6dee6fa",                        [{"marker":{"color":"dodgerblue","colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"opacity":0.5,"size":10},"mode":"markers","name":"y_true","x":[-6.7176618576049805,-3.959944248199463,2.286510467529297,1.6928858757019043,-6.334113121032715,1.1406159400939941,-3.065351963043213,-3.6293344497680664,4.777597904205322,-4.187119007110596,3.5227627754211426,-5.667290687561035,0.2820591330528259,1.3412482738494873,-4.6002516746521,-4.4129462242126465,-4.477239608764648,0.36181965470314026,-1.0188462734222412,3.8434090614318848,4.787766933441162,-6.956237316131592,-3.9571175575256348,0.5049771666526794,0.1757121980190277,2.210317373275757,-0.2806116044521332,-2.225250482559204,-8.878240585327148,0.2945379316806793,-4.455855846405029,-8.029570579528809,-3.9516429901123047,1.4794938564300537,-2.899789810180664,3.0139033794403076,0.7346632480621338,-1.5069506168365479,3.348696231842041,-8.450899124145508,5.787709712982178,-0.20371027290821075,7.278881072998047,-5.801374912261963,2.744999647140503,1.458044171333313,-5.641223907470703,-2.874687671661377,-1.165177583694458,2.8216474056243896,1.772162914276123,-8.667305946350098,6.523378849029541,-3.1852481365203857,-2.073751926422119,-6.626159191131592,-4.613024711608887,0.498739629983902,3.479426860809326,-2.277435779571533,-4.546464920043945,-1.5413775444030762,-5.935418605804443,-0.7902435660362244,5.418240070343018,5.060822010040283,-5.736151218414307,1.2187002897262573,-4.088942050933838,2.889082431793213,-3.3989291191101074,3.4537570476531982,-7.86333703994751,-4.043548583984375,7.50315523147583,6.512842655181885,-1.1054198741912842,2.1137542724609375,-2.830622434616089,-2.2767438888549805,6.957292556762695,-4.267752170562744,-5.124457836151123,-1.4040014743804932,1.6676952838897705,4.446939468383789,-0.5525363087654114,-3.500974655151367,-3.154291868209839,0.8772937059402466,1.2590299844741821,-7.024039268493652,-3.0986900329589844,-1.6427043676376343,-3.0839197635650635,6.716394901275635,1.469206690788269,4.5497846603393555,-7.562637805938721,-7.697123050689697,-2.163341999053955,-5.655681133270264,3.6859610080718994,-5.633155345916748,7.23395299911499,7.546210765838623,-2.53774356842041,-6.043471813201904,-7.373968601226807,-8.047009468078613,2.2890713214874268,-2.6454598903656006,-6.366466045379639,-7.499997615814209,2.4039723873138428,-6.520339012145996,7.563732624053955,-6.822384834289551,3.1689703464508057,0.3598828911781311,7.302177906036377,1.963905692100525,8.145941734313965,-3.6073050498962402,-1.9251505136489868,-1.6238038539886475,-3.8433992862701416,1.684505820274353,4.13519287109375,-6.111810684204102,1.332152247428894,2.321869134902954,1.963686466217041,-3.078274726867676,-8.618027687072754,-4.695083141326904,-5.654715538024902,-3.032442569732666,-2.998946189880371,-7.573868274688721,3.3842194080352783,0.8977653980255127,-3.6226913928985596,-5.560288429260254,2.343996047973633,3.2516469955444336,-2.0197529792785645,-4.924756050109863,-2.462568521499634,-8.750182151794434],"y":[4.686705112457275,10.485825538635254,1.3023914098739624,1.9910324811935425,4.239578723907471,1.8682785034179688,3.8277249336242676,-2.79254412651062,2.148902416229248,10.710039138793945,6.024324893951416,-4.122325897216 ...
